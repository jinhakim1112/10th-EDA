# %%
import pandas as pd

# 서울시 자치구별 인구 데이터
people_seoul = pd.read_csv('D:/연세/Data Science Lab/EDA project/서울특별시 인구/자치구별+총인구(추계인구)_20230723020537.csv')
people_seoul.head()
# Out:
#    자치구별(1)  자치구별(2)     2020   2020.1   2020.2     2021   2021.1   2021.2  \
# 0  자치구별(1)  자치구별(2)      총인구      총인구      총인구      총인구      총인구      총인구
# 1  자치구별(1)  자치구별(2)       소계       남자       여자       소계       남자       여자
# 2       합계       소계  9617795  4666345  4951450  9501528  4597665  4903863
# 3       합계      종로구   152056    73553    78503   149705    72057    77648
# 4       합계       중구   129218    62445    66773   127427    61301    66126
#
#       2022   2022.1   2022.2     2023   2023.1   2023.2     2024   2024.1  \
# 0      총인구      총인구      총인구      총인구      총인구      총인구      총인구      총인구
# 1       소계       남자       여자       소계       남자       여자       소계       남자
# 2  9411443  4546159  4865284  9338274  4503704  4834570  9271433  4464680
# 3   147145    70539    76606   144004    68797    75207   141438    67406
# 4   126355    60607    65748   124454    59543    64911   122700    58600
#
# ...

# %%
# 각 자치구별 지하철역 데이터
seoul_subway = pd.read_csv('D:/연세/Data Science Lab/EDA project/서울교통공사_자치구별지하철역정보_20230531.csv', encoding = 'cp949')
seoul_subway
# Out:
#      자치구                                            해당역(호선)  역개수
# 0    강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...   21
# 1    강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...   14
# 2    강북구                             수유(4), 미아(4), 미아사거리(4)    3
# 3    강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...    9
# 4    관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)    4
# 5    광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...   11
# 6    구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...    7
# 7    금천구                                         가산디지털단지(7)    1
# 8    노원구  당고개(4), 상계(4), 노원(4), 석계(6), 태릉입구(6), 화랑대(6), ...   13
# 9    도봉구                               창동(4), 쌍문(4), 도봉산(7)    3
# 10  동대문구      신설동(1), 제기동(1), 청량리(1), 용두(2), 신설동(2), 장한평(5)    6
# 11   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...   12
# 12   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...   16
# ...

# %%
# 지하철역 별 승차총승객수와 하차총승객수
subway_onoff = pd.read_csv('D:/연세/Data Science Lab/EDA project/서울시 지하철호선별 역별 승하차 인원 정보 2022년.csv', encoding = 'cp949', index_col = None)
subway_onoff.head()
# Out:
#          사용일자  노선명    역명  승차총승객수    하차총승객수  등록일자
# 20220101  3호선   수서  7370    7076  20220104   NaN
# 20220101  3호선  학여울   461     473  20220104   NaN
# 20220101  3호선   대청  3224    2903  20220104   NaN
# 20220101  3호선   일원  3321    2803  20220104   NaN
# 20220101  경원선   창동     1       0  20220104   NaN

# %%
# 서울시 지하철호선별 역별 승하차 인원 정보 2022년.csv의 사용일자 열이 인덱스로 사용되는 오류 수정(1)
subway_onoff.reset_index(inplace=True)
subway_onoff.head()
# Out:
#       index 사용일자  노선명    역명  승차총승객수    하차총승객수  등록일자
# 0  20220101  3호선   수서  7370    7076  20220104   NaN
# 1  20220101  3호선  학여울   461     473  20220104   NaN
# 2  20220101  3호선   대청  3224    2903  20220104   NaN
# 3  20220101  3호선   일원  3321    2803  20220104   NaN
# 4  20220101  경원선   창동     1       0  20220104   NaN

# %%
# 서울시 지하철호선별 역별 승하차 인원 정보 2022년.csv의 사용일자 열이 인덱스로 사용되는 오류 수정(2)
subway_onoff = subway_onoff.drop(columns=['하차총승객수', '등록일자'])
subway_onoff.head()
# Out:
#       index 사용일자  노선명    역명  승차총승객수
# 0  20220101  3호선   수서  7370    7076
# 1  20220101  3호선  학여울   461     473
# 2  20220101  3호선   대청  3224    2903
# 3  20220101  3호선   일원  3321    2803
# 4  20220101  경원선   창동     1       0

# %%
new_column_names = {'index': '사용일자', '사용일자': '노선명', '노선명': '역명', '역명': '승차총승객수', '승차총승객수': '하차총승객수'}
subway_onoff.rename(columns = new_column_names, inplace = True)
subway_onoff.head()
# Out:
#        사용일자  노선명   역명  승차총승객수  하차총승객수
# 0  20220101  3호선   수서    7370    7076
# 1  20220101  3호선  학여울     461     473
# 2  20220101  3호선   대청    3224    2903
# 3  20220101  3호선   일원    3321    2803
# 4  20220101  경원선   창동       1       0

# %%
# 자치구 이름으로 변수를 만들어서 해당 자치구에 속해 있는 지하철역 이름을 리스트로 저장

gangnam = seoul_subway.loc[0, '해당역(호선)'].split(',') #동남1생활권(a) - 강남
seocho = seoul_subway.loc[14, '해당역(호선)'].split(',') #동남1생활권(a) - 서초

songpa = seoul_subway.loc[17, '해당역(호선)'].split(',') #동남2생활권 - 송파
gangdong = seoul_subway.loc[1, '해당역(호선)'].split(',') #동남2생활권 - 강동

gangseo = seoul_subway.loc[3, '해당역(호선)'].split(',') # 서남1생활권 - 강서
yangcheon = seoul_subway.loc[18, '해당역(호선)'].split(',') # 서남1생활권 - 양천

yeongdeungpo = seoul_subway.loc[19, '해당역(호선)'].split(',') # 서남2생활권 - 영등포
guro = seoul_subway.loc[6, '해당역(호선)'].split(',') # 서남2생활권 - 구로
geumcheon = seoul_subway.loc[7, '해당역(호선)'].split(',') # 서남2생활권 - 금천

dongjak = seoul_subway.loc[11, '해당역(호선)'].split(',') # 서남3생활권 - 동작
gwanak = seoul_subway.loc[4, '해당역(호선)'].split(',') # 서남3생활권 - 관악

eunpyeong = seoul_subway.loc[21, '해당역(호선)'].split(',') # 서북생활권 - 은평
seodaemun = seoul_subway.loc[13, '해당역(호선)'].split(',') # 서북생활권 - 서대문
mapo = seoul_subway.loc[12, '해당역(호선)'].split(',') # 서북생활권 - 마포

yongsan = seoul_subway.loc[20, '해당역(호선)'].split(',') # 도심생활권 - 용산
junggu = seoul_subway.loc[23, '해당역(호선)'].split(',') # 도심생활권 - 중구
jongro = seoul_subway.loc[22, '해당역(호선)'].split(',') # 도심생활권 - 종로

sungdong = seoul_subway.loc[15, '해당역(호선)'].split(',') # 동북1생활권 - 성동
dongdaemun = seoul_subway.loc[10, '해당역(호선)'].split(',') # 동북1생활권 - 동대문
gwangjin = seoul_subway.loc[5, '해당역(호선)'].split(',') # 동북1생활권 - 광진
junglang = seoul_subway.loc[24, '해당역(호선)'].split(',') # 동북1생활권 - 중랑

sungbuk = seoul_subway.loc[16, '해당역(호선)'].split(',') # 동북2생활권 - 성북
gangbuk = seoul_subway.loc[2, '해당역(호선)'].split(',') # 동북2생활권 - 강북
dobong = seoul_subway.loc[9, '해당역(호선)'].split(',') # 동북2생활권 - 도봉
nowon = seoul_subway.loc[8, '해당역(호선)'].split(',') # 동북2생활권 - 노원

# %%
# 자치구별 인구수를 파악하기 쉽게 다시 생성
jachigu = people_seoul['자치구별(2)']
jachigu_people = people_seoul['2023']
jachigu2 = pd.concat([jachigu, jachigu_people], axis = 1)
jachigu2 = jachigu2.drop([0, 1])
print(jachigu2)
# Out:
#    자치구별(2)     2023
# 2       소계  9338274
# 3      종로구   144004
# 4       중구   124454
# 5      용산구   218319
# 6      성동구   277297
# 7      광진구   343035
# 8     동대문구   342569
# 9      중랑구   377982
# 10     성북구   430415
# 11     강북구   284312
# 12     도봉구   300420
# 13     노원구   488572
# 14     은평구   454878
# 15    서대문구   308291
# 16     마포구   358810
# 17     양천구   424369
# 18     강서구   554566
# 19     구로구   417020
# 20     금천구   248038
# 21    영등포구   397320
# 22     동작구   383944
# 23     관악구   489080
# 24     서초구   383645
# 25     강남구   504077
# 26     송파구   638664
# 27     강동구   444193

# %%
for date in range(20220501, 20220532):
    subway_may = subway_onoff.drop(subway_onoff[subway_onoff['사용일자'] != date].index)
    globals()[f"subway_onoff_{date}"] = subway_may.groupby('역명').sum().reset_index()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3805179007.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   globals()[f"subway_onoff_{date}"] = subway_may.groupby('역명').sum().reset_index()
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3805179007.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   globals()[f"subway_onoff_{date}"] = subway_may.groupby('역명').sum().reset_index()
# ...

# %%
merged_subway_onoff = pd.concat([subway_onoff_20220503, subway_onoff_20220502, subway_onoff_20220503, subway_onoff_20220504, subway_onoff_20220505, subway_onoff_20220506, subway_onoff_20220507, subway_onoff_20220508, subway_onoff_20220509, subway_onoff_20220510, subway_onoff_20220511, subway_onoff_20220512, subway_onoff_20220513, subway_onoff_20220514, subway_onoff_20220515, subway_onoff_20220516, subway_onoff_20220517, subway_onoff_20220518, subway_onoff_20220519, subway_onoff_20220520, subway_onoff_20220521, subway_onoff_20220522, subway_onoff_20220523, subway_onoff_20220524, subway_onoff_20220525, subway_onoff_20220526, subway_onoff_20220527, subway_onoff_20220528, subway_onoff_20220529, subway_onoff_20220530, subway_onoff_20220531], axis = 0)
average_subway_onoff = merged_subway_onoff.groupby('역명').mean()
average_subway_onoff.drop(columns=['사용일자'], inplace = True)
average_subway_onoff.head()
# Out:
#                 승차총승객수        하차총승객수
# 역명
# 4.19민주묘지   3556.548387   3357.903226
# 가능         6836.322581   6484.677419
# 가락시장      15520.419355  16261.903226
# 가산디지털단지   53472.903226  56123.032258
# 가양        19964.258065  19192.096774

# %%
average_subway_onoff.reset_index(inplace=True)
average_subway_onoff.head()
# Out:
#          역명        승차총승객수        하차총승객수
# 0  4.19민주묘지   3556.548387   3357.903226
# 1        가능   6836.322581   6484.677419
# 2      가락시장  15520.419355  16261.903226
# 3   가산디지털단지  53472.903226  56123.032258
# 4        가양  19964.258065  19192.096774

# %%
jachigu_name = [gangnam, seocho, songpa, gangdong, gangseo, yangcheon, yeongdeungpo, guro, geumcheon, dongjak, gwanak, eunpyeong, seodaemun, mapo, yongsan, junggu, jongro, sungdong, dongdaemun, gwangjin, junglang, sungbuk, gangbuk, dobong, nowon]

# 역이름 뒤에 괄호로 호선 표시된 부분 제거
for j in jachigu_name:
    for i in range(len(j)):
        j[i] = j[i][:-3]
        
# 자치구별 지하철역 이름을 모아놓은 리스트에서 첫 번째 원소를 제외하고 이름 앞에 띄어쓰기 하나가 추가되어 있는 문제 해결
for k in jachigu_name:
    for l in range(1, len(k)):
        k[l] = k[l][1:]

# %%
#지하철역 이름 뒤에 괄호로 표시된 부역명 제거
list_name = average_subway_onoff['역명'].tolist()
list_subway = []

for name in list_name:
    name = name.split('(')[0]
    list_subway.append(name)
    
average_subway_onoff['역명'] = list_subway

# %%
# jachigu_name 내용 확인
for l in range(len(jachigu_name)):
    jachigu_name[l] = pd.Series(jachigu_name[l]).drop_duplicates().tolist()
    print(jachigu_name[l])
# Out:
# ['삼성', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사']
# ['교대', '서초', '방배', '잠원', '고속터미널', '남부터미널', '양재', '남태령', '반포', '내방']
# ['잠실나루', '잠실', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원', '방이', '개롱', '거여', '마천', '몽촌토성', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제']
# ['천호', '강동', '길동', '굽은다리', '명일', '고덕', '상일동', '둔촌동', '강일', '암사', '강동구청', '둔촌오륜', '중앙보훈병원']
# ['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산']
# ['양천구청', '신정네거리', '신정', '목동', '오목교']
# ['문래', '영등포구청', '당산', '양평', '영등포시장', '신길', '여의도', '여의나루', '신풍']
# ['구로디지털단지', '대림', '신도림', '도림천', '남구로', '천왕', '온수']
# ['가산디지털단지']
# ['사당', '신대방', '동작', '이수', '남성', '숭실대입구', '상도', '장승배기', '신대방삼거리', '보라매']
# ['낙성대', '서울대입구', '봉천', '신림']
# ['구파발', '연신내', '불광', '녹번', '응암', '역촌', '독바위', '구산', '새절', '증산', '디지털미디어시티']
# ['충정로', '홍제', '무악재', '독립문']
# ...

# %%
# 서울시 전체의 역 개수 확인
number = 0

for i in range(len(jachigu_name)):
    number += len(jachigu_name[i])

print(number)
# Out:
# 234

# %%
data = pd.DataFrame()

for a in range(len(jachigu_name)):
    for b in jachigu_name[a]:
        data1 = average_subway_onoff.loc[average_subway_onoff['역명'] == b]
        data = pd.concat([data, data1], ignore_index=True)

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

print(data)
# Out:
#       역명        승차총승객수        하차총승객수
# 0     삼성  47138.193548  48003.838710
# 1     선릉  60672.000000  61560.000000
# 2     역삼  43562.677419  49715.967742
# 3     강남  77177.774194  77741.612903
# 4    압구정  29465.774194  31978.774194
# ..   ...           ...           ...
# 229  수락산  12643.161290  12218.193548
# 230   마들  12345.903226  11425.741935
# 231   중계  14021.580645  12668.096774
# 232   하계  17411.225806  16147.290323
# 233   공릉  12282.032258  12008.870968
#
# [234 rows x 3 columns]

# %%
# data 전체 확인
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(data)
# Out:
#             역명        승차총승객수        하차총승객수
# 0           삼성  47138.193548  48003.838710
# 1           선릉  60672.000000  61560.000000
# 2           역삼  43562.677419  49715.967742
# 3           강남  77177.774194  77741.612903
# 4          압구정  29465.774194  31978.774194
# 5           신사  28876.677419  30599.612903
# 6           매봉  11265.870968  10938.000000
# 7           도곡  11826.548387  11680.000000
# 8           대치  10769.322581  10557.096774
# 9          학여울   2652.032258   2711.774194
# 10          대청   9516.935484   8745.096774
# 11          일원   9543.225806   9154.838710
# 12          수서  30554.612903  31071.677419
# 13          청담  17567.709677  19734.806452
# 14        강남구청  23611.000000  26837.129032
# 15          학동  20771.322581  22261.483871
# 16          논현  17979.419355  19659.483871
# 17          언주   9369.225806   9644.677419
# 18         선정릉  15723.193548  17154.838710
# 19        삼성중앙   6178.709677   6509.870968
# 20         봉은사  16314.064516  16854.903226
# ...

# %%
# data_final에서 자치구별 지하철역 개수만큼 잘라서 새로 만든 변수에 각각 지정
for i in range(25):
    change = data.loc[:len(jachigu_name[i])-1]
    globals()[f"df{i}"] = change
    data.drop(index = range(len(jachigu_name[i])), inplace=True)
    data.reset_index(drop=True, inplace=True)

# %%
# 강남구
df0[['승차총승객수', '하차총승객수']] = df0[['승차총승객수', '하차총승객수']] / 504077

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df0.rename(columns = column_names_change, inplace = True)
df0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\101963330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0[['승차총승객수', '하차총승객수']] = df0[['승차총승객수', '하차총승객수']] / 504077
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\101963330.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0     삼성         0.093514         0.095231
# 1     선릉         0.120363         0.122124
# 2     역삼         0.086421         0.098628
# ...

# %%
print(df0['승차총승객수/해당자치구인구수'].idxmin())
print(df0['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 9
# 9

# %%
import matplotlib.pyplot as plt

plt.boxplot([df0['승차총승객수/해당자치구인구수'], df0['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df0['승차총승객수/해당자치구인구수'], df0['하차총승객수/해당자치구인구수'], alpha = 0.7) 
plt.show()

# %%
# 서초구
df1[['승차총승객수', '하차총승객수']] = df1[['승차총승객수', '하차총승객수']] / 383645

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df1.rename(columns = column_names_change, inplace = True)
df1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2594609173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['승차총승객수', '하차총승객수']] = df1[['승차총승객수', '하차총승객수']] / 383645
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2594609173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0     교대         0.114610         0.113546
# 1     서초         0.051872         0.049496
# 2     방배         0.045169         0.046806
# ...

# %%
print(df1['승차총승객수/해당자치구인구수'].idxmin())
print(df1['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 7
# 7

# %%
plt.boxplot([df1['승차총승객수/해당자치구인구수'], df1['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df1['승차총승객수/해당자치구인구수'], df1['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 송파구
df2[['승차총승객수', '하차총승객수']] = df2[['승차총승객수', '하차총승객수']] / 638664

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df2.rename(columns = column_names_change, inplace = True)
df2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\908483990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['승차총승객수', '하차총승객수']] = df2[['승차총승객수', '하차총승객수']] / 638664
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\908483990.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns = column_names_change, inplace = True)
#        역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    잠실나루         0.021289         0.020714
# 1      잠실         0.133855         0.136651
# 2    잠실새내         0.032820         0.033062
# ...

# %%
print(df2['승차총승객수/해당자치구인구수'].idxmin())
print(df2['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 21
# 21

# %%
plt.boxplot([df2['승차총승객수/해당자치구인구수'], df2['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df2['승차총승객수/해당자치구인구수'], df2['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 강동구
df3[['승차총승객수', '하차총승객수']] = df3[['승차총승객수', '하차총승객수']] / 444193

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df3.rename(columns = column_names_change, inplace = True)
df3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\131719066.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[['승차총승객수', '하차총승객수']] = df3[['승차총승객수', '하차총승객수']] / 444193
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\131719066.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns = column_names_change, inplace = True)
#         역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0       천호         0.073212         0.078271
# 1       강동         0.039384         0.037557
# 2       길동         0.017201         0.017660
# ...

# %%
print(df3['승차총승객수/해당자치구인구수'].idxmin())
print(df3['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 11
# 11

# %%
plt.boxplot([df3['승차총승객수/해당자치구인구수'], df3['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df3['승차총승객수/해당자치구인구수'], df3['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 강서구
df4[['승차총승객수', '하차총승객수']] = df4[['승차총승객수', '하차총승객수']] / 554566

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df4.rename(columns = column_names_change, inplace = True)
df4
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1456704614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4[['승차총승객수', '하차총승객수']] = df4[['승차총승객수', '하차총승객수']] / 554566
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1456704614.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.rename(columns = column_names_change, inplace = True)
#      역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    방화         0.011715         0.011163
# 1   개화산         0.009688         0.009173
# 2  김포공항         0.050715         0.047977
# ...

# %%
print(df4['승차총승객수/해당자치구인구수'].idxmin())
print(df4['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 1
# 1

# %%
plt.boxplot([df4['승차총승객수/해당자치구인구수'], df4['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df4['승차총승객수/해당자치구인구수'], df4['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 양천구
df5[['승차총승객수', '하차총승객수']] = df5[['승차총승객수', '하차총승객수']] / 424369

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df5.rename(columns = column_names_change, inplace = True)
df5
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2732729335.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5[['승차총승객수', '하차총승객수']] = df5[['승차총승객수', '하차총승객수']] / 424369
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2732729335.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0   양천구청         0.015550         0.015777
# 1  신정네거리         0.023628         0.023919
# 2     신정         0.030952         0.024986
# ...

# %%
print(df5['승차총승객수/해당자치구인구수'].idxmin())
print(df5['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 0
# 0

# %%
plt.boxplot([df5['승차총승객수/해당자치구인구수'], df5['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df5['승차총승객수/해당자치구인구수'], df5['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 영등포구
df6[['승차총승객수', '하차총승객수']] = df6[['승차총승객수', '하차총승객수']] / 397320

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df6.rename(columns = column_names_change, inplace = True)
df6
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2580732680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6[['승차총승객수', '하차총승객수']] = df6[['승차총승객수', '하차총승객수']] / 397320
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2580732680.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0     문래         0.050262         0.052072
# 1  영등포구청         0.059428         0.061773
# 2     당산         0.090058         0.096849
# ...

# %%
print(df6['승차총승객수/해당자치구인구수'].idxmin())
print(df6['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 4
# 3

# %%
plt.boxplot([df6['승차총승객수/해당자치구인구수'], df6['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df6['승차총승객수/해당자치구인구수'], df6['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 구로구
df7[['승차총승객수', '하차총승객수']] = df7[['승차총승객수', '하차총승객수']] / 417020

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df7.rename(columns = column_names_change, inplace = True)
df7
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1889698773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7[['승차총승객수', '하차총승객수']] = df7[['승차총승객수', '하차총승객수']] / 417020
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1889698773.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.rename(columns = column_names_change, inplace = True)
#         역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0  구로디지털단지         0.128980         0.128202
# 1       대림         0.075212         0.076390
# 2      신도림         0.122264         0.123682
# ...

# %%
print(df7['승차총승객수/해당자치구인구수'].idxmin())
print(df7['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 3
# 3

# %%
plt.boxplot([df7['승차총승객수/해당자치구인구수'], df7['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df7['승차총승객수/해당자치구인구수'], df7['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 금천구
df8[['승차총승객수', '하차총승객수']] = df8[['승차총승객수', '하차총승객수']] / 248038

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df8.rename(columns = column_names_change, inplace = True)
df8
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2965360269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8[['승차총승객수', '하차총승객수']] = df8[['승차총승객수', '하차총승객수']] / 248038
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2965360269.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8.rename(columns = column_names_change, inplace = True)
#         역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0  가산디지털단지         0.215584         0.226268

# %%
plt.boxplot([df8['승차총승객수/해당자치구인구수'], df8['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df8['승차총승객수/해당자치구인구수'], df8['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 동작구
df9[['승차총승객수', '하차총승객수']] = df9[['승차총승객수', '하차총승객수']] / 383944

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df9.rename(columns = column_names_change, inplace = True)
df9
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2312635558.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9[['승차총승객수', '하차총승객수']] = df9[['승차총승객수', '하차총승객수']] / 383944
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2312635558.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9.rename(columns = column_names_change, inplace = True)
#        역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0      사당         0.166617         0.168849
# 1     신대방         0.067462         0.064637
# 2      동작         0.010379         0.009934
# ...

# %%
print(df9['승차총승객수/해당자치구인구수'].idxmin())
print(df9['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 2
# 2

# %%
plt.boxplot([df9['승차총승객수/해당자치구인구수'], df9['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df9['승차총승객수/해당자치구인구수'], df9['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 관악구
df10[['승차총승객수', '하차총승객수']] = df10[['승차총승객수', '하차총승객수']] / 489080

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df10.rename(columns = column_names_change, inplace = True)
df10
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\47268503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10[['승차총승객수', '하차총승객수']] = df10[['승차총승객수', '하차총승객수']] / 489080
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\47268503.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    낙성대         0.054614         0.052550
# 1  서울대입구         0.094909         0.093128
# 2     봉천         0.046145         0.042049
# ...

# %%
print(df10['승차총승객수/해당자치구인구수'].idxmin())
print(df10['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 2
# 2

# %%
plt.boxplot([df10['승차총승객수/해당자치구인구수'], df10['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df10['승차총승객수/해당자치구인구수'], df10['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 은평구
df11[['승차총승객수', '하차총승객수']] = df11[['승차총승객수', '하차총승객수']] / 454878

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df11.rename(columns = column_names_change, inplace = True)
df11
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2078731219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11[['승차총승객수', '하차총승객수']] = df11[['승차총승객수', '하차총승객수']] / 454878
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2078731219.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11.rename(columns = column_names_change, inplace = True)
#           역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0        구파발         0.045041         0.043825
# 1        연신내         0.078224         0.073599
# 2         불광         0.044694         0.047298
# ...

# %%
print(df11['승차총승객수/해당자치구인구수'].idxmin())
print(df11['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 6
# 6

# %%
plt.boxplot([df11['승차총승객수/해당자치구인구수'], df11['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df11['승차총승객수/해당자치구인구수'], df11['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 서대문구
df12[['승차총승객수', '하차총승객수']] = df12[['승차총승객수', '하차총승객수']] / 308291

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df12.rename(columns = column_names_change, inplace = True)
df12
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1060925830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12[['승차총승객수', '하차총승객수']] = df12[['승차총승객수', '하차총승객수']] / 308291
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1060925830.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.rename(columns = column_names_change, inplace = True)
#     역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0  충정로         0.042766         0.044878
# 1   홍제         0.056634         0.053304
# 2  무악재         0.012218         0.012532
# ...

# %%
print(df12['승차총승객수/해당자치구인구수'].idxmin())
print(df12['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 2
# 2

# %%
plt.boxplot([df12['승차총승객수/해당자치구인구수'], df12['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df12['승차총승객수/해당자치구인구수'], df12['하차총승객수/해당자치구인구수'], alpha = 0.7) 
plt.show()

# %%
# 마포구
df13[['승차총승객수', '하차총승객수']] = df13[['승차총승객수', '하차총승객수']] / 358810

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df13.rename(columns = column_names_change, inplace = True)
df13
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\63885068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13[['승차총승객수', '하차총승객수']] = df13[['승차총승객수', '하차총승객수']] / 358810
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\63885068.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df13.rename(columns = column_names_change, inplace = True)
#         역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0       합정         0.123934         0.131150
# 1     홍대입구         0.205457         0.219515
# 2       신촌         0.097030         0.099414
# ...

# %%
print(df13['승차총승객수/해당자치구인구수'].idxmin())
print(df13['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 8
# 8

# %%
plt.boxplot([df13['승차총승객수/해당자치구인구수'], df13['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df13['승차총승객수/해당자치구인구수'], df13['하차총승객수/해당자치구인구수'], alpha = 0.7) 
plt.show()

# %%
# 용산구
df14[['승차총승객수', '하차총승객수']] = df14[['승차총승객수', '하차총승객수']] / 218319

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df14.rename(columns = column_names_change, inplace = True)
df14
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2815469364.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14[['승차총승객수', '하차총승객수']] = df14[['승차총승객수', '하차총승객수']] / 218319
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2815469364.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df14.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    서울역         0.355029         0.360014
# 1   숙대입구         0.062647         0.060847
# 2    삼각지         0.057201         0.055975
# ...

# %%
print(df14['승차총승객수/해당자치구인구수'].idxmin())
print(df14['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 6
# 6

# %%
plt.boxplot([df14['승차총승객수/해당자치구인구수'], df14['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df14['승차총승객수/해당자치구인구수'], df14['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 중구
df15[['승차총승객수', '하차총승객수']] = df15[['승차총승객수', '하차총승객수']] / 124454

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df15.rename(columns = column_names_change, inplace = True)
df15
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\958284950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15[['승차총승객수', '하차총승객수']] = df15[['승차총승객수', '하차총승객수']] / 124454
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\958284950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15.rename(columns = column_names_change, inplace = True)
#            역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0          시청         0.337842         0.333652
# 1       을지로입구         0.288371         0.299073
# 2       을지로3가         0.244171         0.249911
# ...

# %%
print(df15['승차총승객수/해당자치구인구수'].idxmin())
print(df15['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 12
# 12

# %%
plt.boxplot([df15['승차총승객수/해당자치구인구수'], df15['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df15['승차총승객수/해당자치구인구수'], df15['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 종로구
df16[['승차총승객수', '하차총승객수']] = df16[['승차총승객수', '하차총승객수']] / 144004

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df16.rename(columns = column_names_change, inplace = True)
df16
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2665058628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16[['승차총승객수', '하차총승객수']] = df16[['승차총승객수', '하차총승객수']] / 144004
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2665058628.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0     종각         0.229334         0.221979
# 1   종로3가         0.338473         0.333728
# 2   종로5가         0.154186         0.153261
# ...

# %%
print(df16['승차총승객수/해당자치구인구수'].idxmin())
print(df16['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 10
# 10

# %%
plt.boxplot([df16['승차총승객수/해당자치구인구수'], df16['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df16['승차총승객수/해당자치구인구수'], df16['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 성동구
df17[['승차총승객수', '하차총승객수']] = df17[['승차총승객수', '하차총승객수']] / 277297

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df17.rename(columns = column_names_change, inplace = True)
df17
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3472919632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df17[['승차총승객수', '하차총승객수']] = df17[['승차총승객수', '하차총승객수']] / 277297
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3472919632.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df17.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0   상왕십리         0.048823         0.046668
# 1    왕십리         0.130439         0.128215
# 2    한양대         0.047376         0.054307
# ...

# %%
print(df17['승차총승객수/해당자치구인구수'].idxmin())
print(df17['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 6
# 6

# %%
plt.boxplot([df17['승차총승객수/해당자치구인구수'], df17['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df17['승차총승객수/해당자치구인구수'], df17['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 동대문구
df18[['승차총승객수', '하차총승객수']] = df18[['승차총승객수', '하차총승객수']] / 342569

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df18.rename(columns = column_names_change, inplace = True)
df18
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\494041636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18[['승차총승객수', '하차총승객수']] = df18[['승차총승객수', '하차총승객수']] / 342569
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\494041636.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18.rename(columns = column_names_change, inplace = True)
#     역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0  신설동         0.054526         0.052947
# 1  제기동         0.048731         0.049784
# 2  청량리         0.108334         0.109444
# ...

# %%
print(df18['승차총승객수/해당자치구인구수'].idxmin())
print(df18['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 3
# 3

# %%
plt.boxplot([df18['승차총승객수/해당자치구인구수'], df18['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df18['승차총승객수/해당자치구인구수'], df18['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 광진구
df19[['승차총승객수', '하차총승객수']] = df19[['승차총승객수', '하차총승객수']] / 343035

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df19.rename(columns = column_names_change, inplace = True)
df19
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1891007294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df19[['승차총승객수', '하차총승객수']] = df19[['승차총승객수', '하차총승객수']] / 343035
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1891007294.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df19.rename(columns = column_names_change, inplace = True)
#        역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    건대입구         0.146645         0.158184
# 1      구의         0.064643         0.062664
# 2      강변         0.093659         0.089165
# ...

# %%
print(df19['승차총승객수/해당자치구인구수'].idxmin())
print(df19['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 6
# 6

# %%
plt.boxplot([df19['승차총승객수/해당자치구인구수'], df19['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df19['승차총승객수/해당자치구인구수'], df19['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 중랑구
df20[['승차총승객수', '하차총승객수']] = df20[['승차총승객수', '하차총승객수']] / 377982

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df20.rename(columns = column_names_change, inplace = True)
df20
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2452599208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df20[['승차총승객수', '하차총승객수']] = df20[['승차총승객수', '하차총승객수']] / 377982
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\2452599208.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df20.rename(columns = column_names_change, inplace = True)
#     역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0  봉화산         0.022104         0.020745
# 1   신내         0.005758         0.005425
# 2   먹골         0.026407         0.025071
# ...

# %%
print(df20['승차총승객수/해당자치구인구수'].idxmin())
print(df20['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 1
# 1

# %%
plt.boxplot([df20['승차총승객수/해당자치구인구수'], df20['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df20['승차총승객수/해당자치구인구수'], df20['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 성북구
df21[['승차총승객수', '하차총승객수']] = df21[['승차총승객수', '하차총승객수']] / 430415

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df21.rename(columns = column_names_change, inplace = True)
df21
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\267773325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df21[['승차총승객수', '하차총승객수']] = df21[['승차총승객수', '하차총승객수']] / 430415
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\267773325.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df21.rename(columns = column_names_change, inplace = True)
#        역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0      길음         0.048965         0.047801
# 1  성신여대입구         0.056059         0.054796
# 2   한성대입구         0.033438         0.032543
# ...

# %%
print(df21['승차총승객수/해당자치구인구수'].idxmin())
print(df21['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 7
# 7

# %%
plt.boxplot([df21['승차총승객수/해당자치구인구수'], df21['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df21['승차총승객수/해당자치구인구수'], df21['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 강북구
df22[['승차총승객수', '하차총승객수']] = df22[['승차총승객수', '하차총승객수']] / 284312

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df22.rename(columns = column_names_change, inplace = True)
df22
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3147243427.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df22[['승차총승객수', '하차총승객수']] = df22[['승차총승객수', '하차총승객수']] / 284312
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3147243427.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df22.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0     수유         0.116619         0.115837
# 1     미아         0.051568         0.049169
# 2  미아사거리         0.094326         0.090643

# %%
print(df22['승차총승객수/해당자치구인구수'].idxmin())
print(df22['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 1
# 1

# %%
plt.boxplot([df22['승차총승객수/해당자치구인구수'], df22['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df22['승차총승객수/해당자치구인구수'], df22['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 도봉구
df23[['승차총승객수', '하차총승객수']] = df23[['승차총승객수', '하차총승객수']] / 342569

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df23.rename(columns = column_names_change, inplace = True)
df23
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3748121572.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df23[['승차총승객수', '하차총승객수']] = df23[['승차총승객수', '하차총승객수']] / 342569
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\3748121572.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df23.rename(columns = column_names_change, inplace = True)
#     역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0   창동         0.073192         0.076957
# 1   쌍문         0.082300         0.074655
# 2  도봉산         0.053512         0.050294

# %%
print(df23['승차총승객수/해당자치구인구수'].idxmin())
print(df23['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 2
# 2

# %%
plt.boxplot([df23['승차총승객수/해당자치구인구수'], df23['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df23['승차총승객수/해당자치구인구수'], df23['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()

# %%
# 노원구
df24[['승차총승객수', '하차총승객수']] = df24[['승차총승객수', '하차총승객수']] / 488572

column_names_change = {'승차총승객수': '승차총승객수/해당자치구인구수', '하차총승객수': '하차총승객수/해당자치구인구수'}
df24.rename(columns = column_names_change, inplace = True)
df24
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1118807333.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df24[['승차총승객수', '하차총승객수']] = df24[['승차총승객수', '하차총승객수']] / 488572
# C:\Users\user\AppData\Local\Temp\ipykernel_8804\1118807333.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df24.rename(columns = column_names_change, inplace = True)
#       역명  승차총승객수/해당자치구인구수  하차총승객수/해당자치구인구수
# 0    당고개         0.018571         0.016666
# 1     상계         0.038849         0.035549
# 2     노원         0.077316         0.084996
# ...

# %%
print(df24['승차총승객수/해당자치구인구수'].idxmin())
print(df24['하차총승객수/해당자치구인구수'].idxmin())
# Out:
# 0
# 0

# %%
plt.boxplot([df24['승차총승객수/해당자치구인구수'], df24['하차총승객수/해당자치구인구수']], showfliers = True)
plt.xticks([1, 2], ['on board', 'get off'])
plt.show()

# %%
plt.scatter(df24['승차총승객수/해당자치구인구수'], df24['하차총승객수/해당자치구인구수'], alpha = 0.7) # 투명도 지정 (0에서 1 사이의 값 입력)
plt.show()
