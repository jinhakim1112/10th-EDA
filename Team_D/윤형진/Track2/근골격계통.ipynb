# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc

# %%
path = "/Users/younyung.gene/__DSL__/EDA/DATA/merged.csv"
df = pd.read_csv(path, encoding = "utf-8")

# %%
plt.rcParams['font.family'] = 'AppleGothic'

# %%
#["주상병코드"] 데이터 대분류로 축소
df["주상병코드_"] = df["주상병코드"].str.slice(0,1)

#주상병코드 M만 남기기
df_M = df.loc[df["주상병코드_"]=="M"]

#데이터 확인
df_M
# Out:
#           기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드      요양개시일자  서식코드  \
# 7261      2020    357865   2611655     2     16    48  2020-01-28     3
# 7348      2020    382736   2866924     2     18    28  2020-01-28     3
# 7411      2020    401342   1760480     1     17    44  2020-01-28     3
# 7587      2020    473517   1782313     1     17    11  2020-01-28     3
# 7600      2020    480051   1753244     2     15    42  2020-01-28     3
# ...        ...       ...       ...   ...    ...   ...         ...   ...
# 11733649  2020    961271   5914641     2      2    41  2020-09-01     2
# 11733650  2020    961271   8197983     2      2    41  2020-07-22     2
# 11733651  2020    961271   7734028     2      2    41  2020-07-22     2
# 11733684  2020    985377  10165832     2      3    41  2020-05-15     2
# 11733702  2020    993682   2479656     1      3    48  2020-01-01     3
#
#           진료과목코드  주상병코드  부상병코드  요양일수  입내원일수  심결가산율  심결요양급여비용총액  심결본인부담금  \
# 7261           1  M5456   K297     1      1   0.15       11540     1500
# 7348           1  M1999   K291     1      1   0.15       11540     1500
# 7411           1   M510  M5456     1      1   0.15       11540     1500
# 7587           1   M170   M130     1      1   0.15       11540     1500
# 7600           1  M1385  M5440     1      1   0.15       11540     1500
# ...          ...    ...    ...   ...    ...    ...         ...      ...
# 11733649       5   M966   Q780     4     18   0.30      910410    67260
# 11733650       5   M966   Q780     0      0   0.30       38390     1910
# 11733651       5   M966   Q780     9     23   0.30     5663890   695150
# 11733684       5  M2380  M6586     2      2   0.25      782820    41840
# 11733702      24  M7954   S509     1      2   0.25      132940    66400
#
#           심결보험자부담금  총처방일수    데이터 기준일자 주상병코드_
# 7261         10040      3  2021-12-28      M
# 7348         10040     10  2021-12-28      M
# 7411         10040      3  2021-12-28      M
# 7587         10040     30  2021-12-28      M
# 7600         10040     15  2021-12-28      M
# ...            ...    ...         ...    ...
# 11733649    843150      0  2021-12-28      M
# 11733650     36480      0  2021-12-28      M
# 11733651   4968740      0  2021-12-28      M
# 11733684    740980      0  2021-12-28      M
# 11733702     66540      0  2021-12-28      M
#
# [2237570 rows x 20 columns]

# %%
#memory free
del df
gc.collect()
# Out:
# 20

# %%
M_count = df_M["주상병코드"].value_counts()

M_count
# Out:
# M170     155964
# M4806    150787
# M5456    131463
# M511     117993
# M750      68848
#           ...
# M8568         1
# M6738         1
# M8315         1
# M9084         1
# M2115         1
# Name: 주상병코드, Length: 2300, dtype: int64

# %% [markdown]
# I109 : 고혈압
# I639 : 상세불명의 뇌 경색증
# I209 : 협심증
# I119 : 심부전이 없는 고혈압성 질병
# I200 : 불안정 협심증

# %%
age = df_M.groupby("연령대코드").mean()
age
# Out:
#          기준년도       가입자 일련번호      진료내역일련번호      성별코드       시도코드      서식코드  \
# 연령대코드
# 1      2020.0  616688.448980  5.927287e+06  1.426797  33.621118  2.942325
# 2      2020.0  613085.529343  5.951931e+06  1.446949  33.938593  2.984454
# 3      2020.0  601857.992349  5.943946e+06  1.428202  33.209863  2.992585
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["입내원일수"])
plt.title("연령대별 평균 입내원일수", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 입내원일수')

# %%
#심결요양급여비용총액 barplot
data = df_M[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 심결요양급여비용총액')

# %%
#심결본인부담금 barplot
data = df_M[["심결본인부담금", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결본인부담금"])
plt.title("연령대별 평균 심결본인부담금", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 심결본인부담금')

# %%
#심결본인보험자 barplot
data = df_M[["심결보험자부담금", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결보험자부담금"])
plt.title("연령대별 평균 심결보험자부담금", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 심결보험자부담금')

# %%
#유아데이터 분석
df_child = df_M.loc[df_M["연령대코드"]==1]
child_I = df_child["주상병코드"].value_counts()
child_I
# Out:
# M303     199
# M4369     96
# M4362     85
# M2550     82
# M214      43
#         ...
# M670       1
# M7952      1
# M5310      1
# M171       1
# M7953      1
# Name: 주상병코드, Length: 142, dtype: int64

# %%
#어린이 질병별 심결요양급여비용총액
data = df_child[["심결요양급여비용총액", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index

data.sort_values(by=["심결요양급여비용총액"])
data = data.head(10)

plt.figure(figsize=(16,8))
plt.bar(data["주상병코드"], data["심결요양급여비용총액"])
plt.title("0~5세 주상병코드별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '0~5세 주상병코드별 평균 심결요양급여비용총액')

# %%
df_I420 = df_child.loc[df_child["주상병코드"]=="I420"]
df_I420
# Out:
#          기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드      요양개시일자  서식코드  \
# 3343809  2020    470452   4969328     1      1    11  2020-11-23     3
# 3455630  2020    547155   4015662     2      1    26  2020-11-10     3
# 3523975  2020    470452   5853260     1      1    11  2020-10-28     3
# 3754396  2020    470452   3858758     1      1    11  2020-11-09     2
# 3788425  2020    547155   3720556     2      1    26  2020-11-10     2
# 3789465  2020    547155   3862430     2      1    26  2020-11-10     2
# 7258068  2020    470452   4969328     1      1    11  2020-11-23     3
# 7369889  2020    547155   4015662     2      1    26  2020-11-10     3
# 7438234  2020    470452   5853260     1      1    11  2020-10-28     3
# 7668655  2020    470452   3858758     1      1    11  2020-11-09     2
# 7702684  2020    547155   3720556     2      1    26  2020-11-10     2
# 7703724  2020    547155   3862430     2      1    26  2020-11-10     2
#
#          진료과목코드 주상병코드 부상병코드  요양일수  입내원일수  심결가산율  심결요양급여비용총액   심결본인부담금  \
# 3343809      11  I420  I517     1      1   0.30       25330      2500
# 3455630      11  I420  I408     1      1   0.25      439400     21900
# 3523975      11  I420  I517     1      1   0.30       30460      3000
# 3754396      11  I420  I517     1     16   0.30      951730     47580
# 3788425      11  I420  H109     0      0   0.30       33610      1680
# 3789465      11  I420  H109    52     52   0.30   210316030  10698980
# 7258068      11  I420  I517     1      1   0.30       25330      2500
# 7369889      11  I420  I408     1      1   0.25      439400     21900
# 7438234      11  I420  I517     1      1   0.30       30460      3000
# 7668655      11  I420  I517     1     16   0.30      951730     47580
# 7702684      11  I420  H109     0      0   0.30       33610      1680
# 7703724      11  I420  H109    52     52   0.30   210316030  10698980
#
#           심결보험자부담금  총처방일수    데이터 기준일자 주상병코드_
# 3343809      22830     60  2021-12-28      I
# 3455630     417500      0  2021-12-28      I
# 3523975      27460      7  2021-12-28      I
# 3754396     904150      0  2021-12-28      I
# 3788425      31930      0  2021-12-28      I
# 3789465  199617050      0  2021-12-28      I
# 7258068      22830     60  2021-12-28      I
# 7369889     417500      0  2021-12-28      I
# 7438234      27460      7  2021-12-28      I
# 7668655     904150      0  2021-12-28      I
# 7702684      31930      0  2021-12-28      I
# 7703724  199617050      0  2021-12-28      I

# %%
sex = df_M.groupby("성별코드").mean()
sex
# Out:
#         기준년도       가입자 일련번호      진료내역일련번호      연령대코드       시도코드      서식코드  \
# 성별코드
# 1     2020.0  613007.798304  6.051159e+06  12.228344  34.810233  2.996380
# 2     2020.0  609855.713841  6.086381e+06  13.044851  34.508771  3.003707
#
#         진료과목코드      요양일수     입내원일수     심결가산율    심결요양급여비용총액       심결본인부담금  \
# 성별코드
# 1     6.358242  1.094770  1.464689  0.167243  68580.402927  17693.068411
# 2     6.264882  1.109844  1.313722  0.165046  68158.287874  17843.140321
#
#           심결보험자부담금     총처방일수
# 성별코드
# 1     50394.814233  7.665712
# 2     50271.788924  8.513652

# %%
df_women = df_M.loc[df_M["성별코드"]==2]
df_men = df_M.loc[df_M["성별코드"]==1]

# %%
#심결요양급여비용총액 barplot
data = df_women[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("여성 연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '여성 연령대별 평균 심결요양급여비용총액')

# %%
#심결요양급여비용총액 barplot
data = df_men[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("남성 연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '남성 연령대별 평균 심결요양급여비용총액')

# %%
#청소년 남자 질병별 금액부담
df_juven_men = df_men.loc[df_men["연령대코드"]==4]

data = df_juven_men[["심결요양급여비용총액", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index


plt.figure(figsize=(20,8))
plt.bar(data["주상병코드"], data["심결요양급여비용총액"])
plt.title("15~19세 남자 주상병코드별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '15~19세 남자 주상병코드별 평균 심결요양급여비용총액')

# %%
#청소년 남자 질병별 금액 본인부담
df_juven_men = df_men.loc[df_men["연령대코드"]==4]

data = df_juven_men[["심결본인부담금", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index


plt.figure(figsize=(20,8))
plt.bar(data["주상병코드"], data["심결본인부담금"])
plt.title("15~19세 남자 주상병코드별 평균 심결본인부담금", fontsize=20)
# Out:
# Text(0.5, 1.0, '15~19세 남자 주상병코드별 평균 심결본인부담금')
