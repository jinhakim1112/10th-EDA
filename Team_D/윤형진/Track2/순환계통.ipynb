# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gc

# %%
path = "/Users/younyung.gene/__DSL__/EDA/DATA/merged.csv"
df = pd.read_csv(path, encoding = "utf-8")

# %%
plt.rcParams['font.family'] = 'AppleGothic'

# %%
#["주상병코드"] 데이터 대분류로 축소
df["주상병코드_"] = df["주상병코드"].str.slice(0,1)

#주상병코드 I만 남기기
df_I = df.loc[df["주상병코드_"]=="I"]

#데이터 확인
df_I
# Out:
#           기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드      요양개시일자  서식코드  \
# 0         2020    334176   1255979     2     16    41  2020-03-20     3
# 1         2020    334176   2274588     2     16    41  2020-02-20     3
# 2         2020    334209   3029252     2     14    41  2020-12-23     3
# 3         2020    334265   5860566     2     15    41  2020-10-19     3
# 4         2020    335323   3079531     2     14    41  2020-12-07     3
# ...        ...       ...       ...   ...    ...   ...         ...   ...
# 11733427  2020    862090   8855694     1      3    45  2020-06-01     2
# 11733536  2020    918701   4711035     1      3    41  2020-10-21     2
# 11733548  2020    923471   8918604     2      3    42  2020-06-11     2
# 11733558  2020    925843  11526742     1      3    48  2020-04-19     3
# 11733604  2020    947924   3720554     2      3    26  2020-11-17     3
#
#           진료과목코드 주상병코드  부상병코드  요양일수  입내원일수  심결가산율  심결요양급여비용총액  심결본인부담금  \
# 0              1  I109   E785     1      1   0.15       11540     1500
# 1              1  I109   E785     1      1   0.15       11540     1500
# 2              1  I109   E119     1      1   0.15       11540     1500
# 3              1  I109   E559     1      1   0.15       11540     1500
# 4              1  I109     F_     1      1   0.15       11540     1500
# ...          ...   ...    ...   ...    ...    ...         ...      ...
# 11733427      11  I109   I959    19     23   0.25     5299180  1284280
# 11733536      11  I880   G930     4      7   0.25     1722630    96600
# 11733548      24  I880   K358     1      4   0.25      408160    20400
# 11733558      24  I880  R1030     1      2   0.25      418680   209300
# 11733604      11  I871   N059     0      0   0.30       11200     6700
#
#           심결보험자부담금  총처방일수    데이터 기준일자 주상병코드_
# 0            10040     30  2021-12-28      I
# 1            10040     30  2021-12-28      I
# 2            10040     60  2021-12-28      I
# 3            10040     60  2021-12-28      I
# 4            10040     30  2021-12-28      I
# ...            ...    ...         ...    ...
# 11733427   4014900      0  2021-12-28      I
# 11733536   1626030      0  2021-12-28      I
# 11733548    387760      0  2021-12-28      I
# 11733558    209380      0  2021-12-28      I
# 11733604      4500      0  2021-12-28      I
#
# [1082748 rows x 20 columns]

# %%
#memory free
del df
gc.collect()
# Out:
# 0

# %%
I_count = df_I["주상병코드"].value_counts()

I_count
# Out:
# I109    773418
# I639     35583
# I209     27683
# I119     17993
# I200     12685
#          ...
# I379         1
# I280         1
# I019         1
# I12          1
# I454         1
# Name: 주상병코드, Length: 404, dtype: int64

# %% [markdown]
# I109 : 고혈압
# I639 : 상세불명의 뇌 경색증
# I209 : 협심증
# I119 : 심부전이 없는 고혈압성 질병
# I200 : 불안정 협심증

# %%
age = df_I.groupby("연령대코드").mean()
age
# Out:
#          기준년도       가입자 일련번호      진료내역일련번호      성별코드       시도코드      서식코드  \
# 연령대코드
# 1      2020.0  622702.952381  4.511640e+06  1.374150  31.401361  2.891156
# 2      2020.0  575898.755708  6.236629e+06  1.397260  34.518265  2.926941
# 3      2020.0  586942.140351  5.767640e+06  1.397661  38.031189  2.861598
# 4      2020.0  598592.152302  5.820320e+06  1.428571  36.469894  2.894923
# 5      2020.0  603151.495232  6.111712e+06  1.471390  32.119210  2.908719
# 6      2020.0  612124.512509  6.064380e+06  1.422001  31.467623  2.955482
# 7      2020.0  627623.499068  5.733428e+06  1.333831  33.116001  2.974450
# 8      2020.0  607805.626167  5.965291e+06  1.263887  33.134360  2.980092
# 9      2020.0  614077.887536  5.974371e+06  1.289964  33.651717  2.990438
# 10     2020.0  608843.975546  5.909877e+06  1.334490  34.163043  3.002262
# 11     2020.0  609321.564498  5.914377e+06  1.416222  33.948799  3.002841
# 12     2020.0  609866.752952  5.950334e+06  1.463446  33.887199  3.022384
# 13     2020.0  611351.276461  5.946520e+06  1.490555  34.191266  3.037813
# 14     2020.0  611442.323379  5.930389e+06  1.524509  33.973987  3.057466
# 15     2020.0  612063.581310  5.926528e+06  1.560689  33.989605  3.084166
# 16     2020.0  608150.563363  5.942670e+06  1.603443  34.185865  3.110085
# 17     2020.0  607295.593170  5.973819e+06  1.637880  35.386058  3.104311
# 18     2020.0  612079.829962  6.062668e+06  1.720855  35.724348  3.118750
#
#           진료과목코드      요양일수     입내원일수     심결가산율    심결요양급여비용총액        심결본인부담금  \
# 연령대코드
# 1      10.727891  1.870748  4.061224  0.238095  3.102604e+06  162155.850340
# 2      13.114155  1.424658  2.837900  0.242808  3.331651e+05   38372.100457
# 3      11.808967  1.518519  2.159844  0.235380  3.126266e+05   43146.510721
# 4       9.265643  1.566706  2.949233  0.232290  5.045895e+05   73172.951594
# 5       5.311989  1.643733  2.236376  0.214510  4.180244e+05   75582.186649
# 6       4.041207  1.149007  1.548565  0.194058  2.177975e+05   41221.651950
# 7       3.735733  1.133905  1.868892  0.188073  1.893062e+05   33761.719508
# 8       2.849910  1.197526  2.172210  0.180501  1.443777e+05   28265.573488
# 9       3.091330  1.211914  1.811042  0.177223  1.160684e+05   23454.850692
# 10      2.753047  1.131511  1.808487  0.172765  9.914872e+04   19256.568710
# 11      2.951131  1.198992  1.722811  0.173698  1.149760e+05   22313.735664
# 12      2.660908  1.124065  1.744158  0.173478  9.448352e+04   18951.512751
# 13      2.592776  1.152748  1.663628  0.175164  9.277678e+04   19346.969056
# 14      2.759904  1.202303  1.716477  0.175763  1.107809e+05   20162.208966
# 15      2.711883  1.220669  2.536008  0.177211  1.104456e+05   19542.899129
# 16      2.810476  1.367087  2.723902  0.176736  1.316658e+05   24330.092797
# 17      3.021195  1.635310  2.846050  0.177520  1.600438e+05   31771.629208
# 18      3.215752  2.245110  3.847928  0.177004  2.190280e+05   45932.411154
#
#            심결보험자부담금      총처방일수
# 연령대코드
# 1      2.940448e+06   5.530612
# 2      2.936298e+05   9.289954
# 3      2.693778e+05   8.619883
# 4      4.310208e+05  16.707202
# 5      3.424422e+05  18.185967
# 6      1.765643e+05  25.054084
# 7      1.555444e+05  29.542708
# 8      1.160243e+05  37.467721
# 9      9.237153e+04  40.088750
# 10     7.972557e+04  42.428775
# 11     9.252350e+04  42.707247
# 12     7.546288e+04  43.869914
# 13     7.332356e+04  45.031686
# 14     9.045297e+04  44.502558
# 15     8.954514e+04  42.925470
# 16     1.057606e+05  41.218811
# 17     1.279810e+05  40.133582
# 18     1.721701e+05  39.546413

# %%
#입내원일수 barplot
data = df_I[["입내원일수", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["입내원일수"])
plt.title("연령대별 평균 입내원일수", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 입내원일수')

# %%
#심결요양급여비용총액 barplot
data = df_I[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 심결요양급여비용총액')

# %%
#심결본인부담금 barplot
data = df_I[["심결본인부담금", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결본인부담금"])
plt.title("연령대별 평균 심결본인부담금", fontsize=20)
# Out:
# Text(0.5, 1.0, '연령대별 평균 심결본인부담금')

# %%
#유아데이터 분석
df_child = df_I.loc[df_I["연령대코드"]==1]
child_I = df_child["주상병코드"].value_counts()
child_I
# Out:
# I889    33
# I880    29
# I891    17
# I639    13
# I420    12
# I370    10
# I471     4
# I459     4
# I340     3
# I99      3
# I254     2
# I071     2
# I429     2
# I350     2
# I620     2
# I109     2
# I881     2
# I272     2
# I499     1
# I781     1
# I491     1
# Name: 주상병코드, dtype: int64

# %%
#어린이 질병별 심결요양급여비용총액
data = df_child[["심결요양급여비용총액", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index


plt.figure(figsize=(16,8))
plt.bar(data["주상병코드"], data["심결요양급여비용총액"])
plt.title("0~5세 주상병코드별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '0~5세 주상병코드별 평균 심결요양급여비용총액')

# %%
df_I420 = df_child.loc[df_child["주상병코드"]=="I420"]
df_I420
# Out:
#          기준년도  가입자 일련번호  진료내역일련번호  성별코드  연령대코드  시도코드      요양개시일자  서식코드  \
# 3343809  2020    470452   4969328     1      1    11  2020-11-23     3
# 3455630  2020    547155   4015662     2      1    26  2020-11-10     3
# 3523975  2020    470452   5853260     1      1    11  2020-10-28     3
# 3754396  2020    470452   3858758     1      1    11  2020-11-09     2
# 3788425  2020    547155   3720556     2      1    26  2020-11-10     2
# 3789465  2020    547155   3862430     2      1    26  2020-11-10     2
# 7258068  2020    470452   4969328     1      1    11  2020-11-23     3
# 7369889  2020    547155   4015662     2      1    26  2020-11-10     3
# 7438234  2020    470452   5853260     1      1    11  2020-10-28     3
# 7668655  2020    470452   3858758     1      1    11  2020-11-09     2
# 7702684  2020    547155   3720556     2      1    26  2020-11-10     2
# 7703724  2020    547155   3862430     2      1    26  2020-11-10     2
#
#          진료과목코드 주상병코드 부상병코드  요양일수  입내원일수  심결가산율  심결요양급여비용총액   심결본인부담금  \
# 3343809      11  I420  I517     1      1   0.30       25330      2500
# 3455630      11  I420  I408     1      1   0.25      439400     21900
# 3523975      11  I420  I517     1      1   0.30       30460      3000
# 3754396      11  I420  I517     1     16   0.30      951730     47580
# 3788425      11  I420  H109     0      0   0.30       33610      1680
# 3789465      11  I420  H109    52     52   0.30   210316030  10698980
# 7258068      11  I420  I517     1      1   0.30       25330      2500
# 7369889      11  I420  I408     1      1   0.25      439400     21900
# 7438234      11  I420  I517     1      1   0.30       30460      3000
# 7668655      11  I420  I517     1     16   0.30      951730     47580
# 7702684      11  I420  H109     0      0   0.30       33610      1680
# 7703724      11  I420  H109    52     52   0.30   210316030  10698980
#
#           심결보험자부담금  총처방일수    데이터 기준일자 주상병코드_
# 3343809      22830     60  2021-12-28      I
# 3455630     417500      0  2021-12-28      I
# 3523975      27460      7  2021-12-28      I
# 3754396     904150      0  2021-12-28      I
# 3788425      31930      0  2021-12-28      I
# 3789465  199617050      0  2021-12-28      I
# 7258068      22830     60  2021-12-28      I
# 7369889     417500      0  2021-12-28      I
# 7438234      27460      7  2021-12-28      I
# 7668655     904150      0  2021-12-28      I
# 7702684      31930      0  2021-12-28      I
# 7703724  199617050      0  2021-12-28      I

# %%
sex = df_I.groupby("성별코드").mean()
sex
# Out:
#         기준년도       가입자 일련번호      진료내역일련번호      연령대코드       시도코드      서식코드  \
# 성별코드
# 1     2020.0  610908.194858  5.948097e+06  13.331731  33.955225  3.051305
# 2     2020.0  609801.318560  5.945847e+06  14.306057  34.514020  3.064969
#
#         진료과목코드      요양일수     입내원일수     심결가산율     심결요양급여비용총액       심결본인부담금  \
# 성별코드
# 1     2.787429  1.278302  2.453909  0.180766  138180.491772  25052.248287
# 2     2.861621  1.341726  1.974594  0.171699  107952.395043  22260.571405
#
#            심결보험자부담금      총처방일수
# 성별코드
# 1     112165.710790  44.492950
# 2      85534.754967  40.713014

# %%
df_women = df_I.loc[df_I["성별코드"]==2]
df_men = df_I.loc[df_I["성별코드"]==1]

# %%
#심결요양급여비용총액 barplot
data = df_women[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("여성 연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '여성 연령대별 평균 심결요양급여비용총액')

# %%
#심결요양급여비용총액 barplot
data = df_men[["심결요양급여비용총액", "연령대코드"]]
data = data.groupby("연령대코드").mean()
data.reset_index()
data["연령대코드"] = data.index


#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["심결요양급여비용총액"])
plt.title("남성 연령대별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '남성 연령대별 평균 심결요양급여비용총액')

# %%
#청소년 남자 질병별 금액부담
df_juven_men = df_men.loc[df_men["연령대코드"]==4]

data = df_juven_men[["심결요양급여비용총액", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index


plt.figure(figsize=(20,8))
plt.bar(data["주상병코드"], data["심결요양급여비용총액"])
plt.title("15~19세 남자 주상병코드별 평균 심결요양급여비용총액", fontsize=20)
# Out:
# Text(0.5, 1.0, '15~19세 남자 주상병코드별 평균 심결요양급여비용총액')

# %%
#청소년 남자 질병별 금액 본인부담
df_juven_men = df_men.loc[df_men["연령대코드"]==4]

data = df_juven_men[["심결본인부담금", "주상병코드"]]
data = data.groupby("주상병코드").mean()
data.reset_index()
data["주상병코드"] = data.index


plt.figure(figsize=(20,8))
plt.bar(data["주상병코드"], data["심결본인부담금"])
plt.title("15~19세 남자 주상병코드별 평균 심결본인부담금", fontsize=20)
# Out:
# Text(0.5, 1.0, '15~19세 남자 주상병코드별 평균 심결본인부담금')

# %%
df_I109 = df_I.loc[df_I["주상병코드"]=="I109"]

data = pd.DataFrame()
data["count"] = df_I109["연령대코드"].value_counts()
data.reset_index()
data["연령대코드"] = data.index

data.sort_values(by=["연령대코드"], inplace= True)

#전처리
data["연령대코드"] = data["연령대코드"].replace(
    {1 : "0~4"
    ,2 : "5~9"
    ,3 : "10~14"
    ,4 : "15~19"
    ,5 : "20~24"
    ,6 : "25~29"
    ,7 : "30~34"
    ,8 : "35~39"
    ,9 : "40~44"
    ,10 : "45~49"
    ,11 : "50~54"
    ,12 : "55~59"
    ,13 : "60~64"
    ,14 : "65~69"
    ,15 : "70~74"
    ,16 : "75~79"
    ,17 : "80~84"
    ,18 : "85+"})

plt.figure(figsize=(16,8))
plt.bar(data["연령대코드"], data["count"])
plt.title("고혈압 연령대별 분포", fontsize=20)
# Out:
# Text(0.5, 1.0, '고혈압 연령대별 분포')

# %%
df_I109 = df_I.loc[df_I["주상병코드"]=="I109"]

data = pd.DataFrame()
data["count"] = df_I109["성별코드"].value_counts()
data.reset_index()
data["성별코드"] = data.index

#전처리
data["성별코드"] = data["성별코드"].replace(
    {1 : "남성"
    ,2 : "여성"})

plt.figure(figsize=(16,8))
plt.bar(data["성별코드"], data["count"])
plt.title("고혈압 성별 분포", fontsize=20)
# Out:
# Text(0.5, 1.0, '고혈압 성별 분포')
